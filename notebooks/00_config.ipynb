# %%
# =========================
# Global Configuration
# =========================

# Athlete info
# MAF Heart Rate (LOCKED)
MAF_HR = 154

# Analysis window
START_DATE = "2025-01-01"
END_DATE = None  # None = latest data

# Training context
PHASE = "MAF_AEROBIC_REBUILD"
RUNS_PER_WEEK = 4

# File paths
RAW_DATA_PATH = "../data/raw/strava_activities_raw.csv"
PROCESSED_DATA_PATH = "../data/processed/runs_cleaned.parquet"

print(f"MAF HR set to: {MAF_HR} bpm")
print(f"Training Phase: {PHASE}")
# Out:
# MAF HR set to: 154 bpm
# Training Phase: MAF_AEROBIC_REBUILD
